# %%
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
import sqlite3 as lite
import numpy as np

# %%
from sqlalchemy import create_engine
sqlite_file = 'sqlite://///Users/Kruthika/Projects/DDL/04-team3/census_v2.db'
engine = create_engine(sqlite_file)
from pandas.io import sql
df=pd.read_sql_table('home_work', engine)
df
# Out:
#           home_lat      home_lon     work_lat      work_lon  num_people
# 0       38.8096324  -77.02283643   38.8096324  -77.02283643           7
# 1       38.8096324  -77.02283643  38.82641682  -76.99597908           2
# 2       38.8096324  -77.02283643  38.83996392  -77.00067029           2
# 3       38.8096324  -77.02283643  38.84042391   -76.9833259           5
# 4       38.8096324  -77.02283643  38.84186464  -77.00192877           2
# 5       38.8096324  -77.02283643  38.85280397  -76.97014327           2
# 6       38.8096324  -77.02283643  38.85919458  -76.97222365          14
# 7       38.8096324  -77.02283643  38.85936131  -76.96323218           2
# 8       38.8096324  -77.02283643  38.86527694  -76.98731555           1
# 9       38.8096324  -77.02283643  38.87019046  -76.96950049           2
# 10      38.8096324  -77.02283643  38.87417369  -76.99976302           4
# 11      38.8096324  -77.02283643  38.87471454   -77.0156375           4
# ...

# %%
from time import sleep

count=0
for index, row in df.iterrows():
    #print row['home_lat'], row['home_lon'], row['work_lat'], row['work_lon']
    source_lat = row['home_lat']
    source_lon = row['home_lon']
    dest_lat= row['work_lat']
    dest_lon= row['work_lon']
    
    headers = {
       'key':'AIzaSyCOI_sLNDF890HW1Qb0U09bDJzIkpVVJ54'
    }
    
    params = {
    # Request parameters
    'origin': source_lat+','+source_lon,
    'destination':dest_lat+','+dest_lon,
    #'origin': dest_lat+','+dest_lon,
    #'destination':source_lat+','+source_lon,
    'alternatives':'false',
    'mode':'transit',
    'traffic_model':'optimistic',
    'departure_time':'now'
    }
    
    r = requests.get('https://maps.googleapis.com/maps/api/directions/json?', params=params, headers=headers)
    if len(r.json()['routes']) != 0:
        if len(json_normalize(r.json()['routes'][0]['legs'][0])) != 0:
            df=json_normalize(r.json()['routes'][0]['legs'][0])

            if 'arrival_time.text' in df:
                df1=df.drop(['steps','traffic_speed_entry','via_waypoint'], axis=1)
                df1['unique_id']=source_lat+'_'+source_lon+'_'+dest_lat+'_'+dest_lon

                df1.to_sql('transit_info_hw', engine,if_exists='append')



            else:

                df1=df.drop(['steps','traffic_speed_entry','via_waypoint'], axis=1)


                df1['arrival_time.text'] = np.nan

                df1=df1.drop(['distance.text','distance.value','duration.text', 'duration.value', u'end_address','end_location.lat',
                              'end_location.lng', u'start_address','start_location.lat','start_location.lng'], axis=1)

                df1['arrival_time.time_zone'] = np.nan
                df1['arrival_time.value'] = np.nan
                df1['departure_time.text'] = np.nan
                df1['departure_time.time_zone'] = np.nan
                df1['departure_time.value'] = np.nan



                df1= pd.concat([df1, df], axis=1)

                df1=df1.drop(['steps','traffic_speed_entry','via_waypoint'], axis=1)

                df1['unique_id']=source_lat+'_'+source_lon+'_'+dest_lat+'_'+dest_lon

                df1.to_sql('transit_info_hw', engine,if_exists='append')



            if len(json_normalize(r.json()['routes'][0]['legs'][0]['steps'])) != 0:
                df2=json_normalize(r.json()['routes'][0]['legs'][0]['steps'])

                if 'transit_details.arrival_stop.location.lat' in df2: 
                    
                    if 'transit_details.line.color' in df2:
                        df2=df2.drop(['polyline.points', 'transit_details.line.color','transit_details.line.agencies', 
                                      'transit_details.line.vehicle.icon','steps'], axis=1)
                    elif 'transit_details.line.text_color' in df2:
                        df2=df2.drop(['polyline.points', 'transit_details.line.text_color','transit_details.line.agencies', 
                                      'transit_details.line.vehicle.icon','steps'], axis=1)
                    else:
                        df2=df2.drop(['polyline.points','transit_details.line.agencies', 'transit_details.line.vehicle.icon','steps'], axis=1)
                        
                    df2['unique_id']=source_lat+'_'+source_lon+'_'+dest_lat+'_'+dest_lon
                       


                   
                    print 'yes'

                else: 
                    
                    if 'steps' in df2:
                        df2=df2.drop(['polyline.points', 'steps'], axis=1)
                    else:
                        df2=df2.drop(['polyline.points'], axis=1)

                    df2['transit_details.arrival_stop.location.lat']=np.nan
                    df2['transit_details.arrival_stop.location.lng']= np.nan
                    df2['transit_details.arrival_stop.name']= np.nan
                    df2['transit_details.arrival_time.text']= np.nan
                    df2['transit_details.arrival_time.time_zone']= np.nan
                    df2['transit_details.arrival_time.value']= np.nan
                    df2['transit_details.departure_stop.location.lat']= np.nan
                    df2['transit_details.departure_stop.location.lng']= np.nan
                    df2['transit_details.departure_stop.name']= np.nan
                    df2['transit_details.departure_time.text']= np.nan
                    df2['transit_details.departure_time.time_zone']= np.nan
                    df2['transit_details.departure_time.value']= np.nan
                    df2['transit_details.headsign']= np.nan
                    df2['transit_details.line.name']= np.nan
                    df2['transit_details.line.short_name']= np.nan
                    df2['transit_details.line.vehicle.name']= np.nan
                    df2['transit_details.line.vehicle.type']= np.nan
                    df2['transit_details.num_stops']=np.nan
                    df2['unique_id']=source_lat+'_'+source_lon+'_'+dest_lat+'_'+dest_lon
                        
                    print 'no'
                df2.to_sql('transit_steps_hw', engine,if_exists='append')

                #print df2['unique_id']   
                    
                    
            else:
                continue

        else:
            continue
    else:
        continue

    #sleep(1)
    count += 1
    print 'Latitude and longitude count value - ',count
    print 'Source and destination pair - ', source_lat, source_lon, dest_lat, dest_lon
    
print "Successful data collection!"

print r
# Out:
# no
# Latitude and longitude count value -  1
# Source and destination pair -  38.8096324 -77.02283643 38.8096324 -77.02283643
# yes
# Latitude and longitude count value -  2
# Source and destination pair -  38.8096324 -77.02283643 38.82641682 -76.99597908
# yes
# Latitude and longitude count value -  3
# Source and destination pair -  38.8096324 -77.02283643 38.83996392 -77.00067029
# yes
# Latitude and longitude count value -  4
# Source and destination pair -  38.8096324 -77.02283643 38.84042391 -76.9833259
# yes
# Latitude and longitude count value -  5
# Source and destination pair -  38.8096324 -77.02283643 38.84186464 -77.00192877
# yes
# Latitude and longitude count value -  6
# Source and destination pair -  38.8096324 -77.02283643 38.85280397 -76.97014327
# yes
# Latitude and longitude count value -  7
# Source and destination pair -  38.8096324 -77.02283643 38.85919458 -76.97222365
# yes
# Latitude and longitude count value -  8
# ...
