# %%
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
import sqlite3 as lite
import numpy as np

# %%
from sqlalchemy import create_engine
sqlite_file = 'sqlite://///Users/Kruthika/Projects/DDL/04-team3/census.db'
engine = create_engine(sqlite_file)
from pandas.io import sql
home_work=pd.read_sql_table('home_work', engine)
#df=home_work.iloc[751:]
df=home_work

# %%
from time import sleep

count=0
for index, row in df.iterrows():
    #print row['home_lat'], row['home_lon'], row['work_lat'], row['work_lon']
    source_lat = row['home_lat']
    source_lon = row['home_lon']
    dest_lat= row['work_lat']
    dest_lon= row['work_lon']
    
    headers = {
        'key':'AIzaSyAUlQnrcpJkb8u6xmL2UuHyPFD5CxWdLPo'
    }
    
    params = {
    # Request parameters
    #'origin': source_lat+','+source_lon,
    #'destination':dest_lat+','+dest_lon,
    'origin': dest_lat+','+dest_lon,
    'destination':source_lat+','+source_lon,
    'alternatives':'false',
    'mode':'car',
    'traffic_model':'optimistic',
    'departure_time':'now'
    }
    
    r = requests.get('https://maps.googleapis.com/maps/api/directions/json?', params=params, headers=headers)
    
    if len(r.json()['routes']) != 0:
        if len(json_normalize(r.json()['routes'][0]['legs'][0])) != 0:
            df=json_normalize(r.json()['routes'][0]['legs'][0])
            df1=df.drop(['steps','traffic_speed_entry','via_waypoint'], axis=1)
            df1['unique_id']=source_lat+'_'+source_lon+'_'+dest_lat+'_'+dest_lon


            df1.to_sql('car_info1', engine,if_exists='append')
        else:
            continue
    else:
        continue
    count += 1
    print 'Latitude and longitude count value - ',count
    print 'Source and destination pair - ', source_lat, source_lon, dest_lat, dest_lon
    
print "Successful data collection!"
# Out:
# Latitude and longitude count value -  1
# Source and destination pair -  38.82797649 -77.0066917 38.91973122 -77.03900634
# Latitude and longitude count value -  2
# Source and destination pair -  38.82797649 -77.0066917 38.92095151 -77.04301181
# Latitude and longitude count value -  3
# Source and destination pair -  38.85280397 -76.97014327 38.85524974 -76.96668369
# Latitude and longitude count value -  4
# Source and destination pair -  38.85280397 -76.97014327 38.8573335 -76.99535535
# Latitude and longitude count value -  5
# Source and destination pair -  38.85280397 -76.97014327 38.85919458 -76.97222365
# Latitude and longitude count value -  6
# Source and destination pair -  38.85280397 -76.97014327 38.86418231 -76.96174845
# Latitude and longitude count value -  7
# Source and destination pair -  38.85280397 -76.97014327 38.86499612 -76.99692675
# Latitude and longitude count value -  8
# Source and destination pair -  38.85280397 -76.97014327 38.86698454 -76.98131728
# Latitude and longitude count value -  9
# Source and destination pair -  38.85280397 -76.97014327 38.87186307 -76.98231638
# Latitude and longitude count value -  10
# Source and destination pair -  38.85280397 -76.97014327 38.87307613 -76.97441584
# Latitude and longitude count value -  11
# Source and destination pair -  38.85280397 -76.97014327 38.87417369 -76.99976302
# Latitude and longitude count value -  12
# Source and destination pair -  38.85280397 -76.97014327 38.87553209 -76.98564186
# Latitude and longitude count value -  13
# Source and destination pair -  38.85280397 -76.97014327 38.87786225 -77.03437325
# Latitude and longitude count value -  14
# Source and destination pair -  38.85280397 -76.97014327 38.87934972 -77.0121947
# Latitude and longitude count value -  15
# Source and destination pair -  38.85280397 -76.97014327 38.88023959 -76.98728308
# Latitude and longitude count value -  16
# Source and destination pair -  38.85280397 -76.97014327 38.88129386 -76.99389976
# Latitude and longitude count value -  17
# Source and destination pair -  38.85280397 -76.97014327 38.88136087 -76.99886936
# Latitude and longitude count value -  18
# Source and destination pair -  38.85280397 -76.97014327 38.88205036 -76.9858834
# Latitude and longitude count value -  19
# Source and destination pair -  38.85280397 -76.97014327 38.88207032 -77.02451512
# Latitude and longitude count value -  20
# Source and destination pair -  38.85280397 -76.97014327 38.88297987 -77.0033724
# Latitude and longitude count value -  21
# Source and destination pair -  38.85280397 -76.97014327 38.88344117 -77.01972757
# Latitude and longitude count value -  22
# Source and destination pair -  38.85280397 -76.97014327 38.89801164 -77.02717393
# Latitude and longitude count value -  23
# Source and destination pair -  38.85280397 -76.97014327 38.89874923 -77.05467122
# Latitude and longitude count value -  24
# Source and destination pair -  38.85280397 -76.97014327 38.89964623 -77.0618145
# Latitude and longitude count value -  25
# Source and destination pair -  38.85280397 -76.97014327 38.90045743 -77.01456899
# Latitude and longitude count value -  26
# Source and destination pair -  38.85280397 -76.97014327 38.90069992 -77.04713527
# Latitude and longitude count value -  27
# Source and destination pair -  38.85280397 -76.97014327 38.9010211 -77.05171998
# Latitude and longitude count value -  28
# Source and destination pair -  38.85280397 -76.97014327 38.90217222 -77.02994423
# Latitude and longitude count value -  29
# Source and destination pair -  38.85280397 -76.97014327 38.9022102 -76.95448698
# Latitude and longitude count value -  30
# Source and destination pair -  38.85280397 -76.97014327 38.90253233 -77.0425942
# Latitude and longitude count value -  31
# Source and destination pair -  38.85280397 -76.97014327 38.90279836 -77.05434784
# Latitude and longitude count value -  32
# Source and destination pair -  38.85280397 -76.97014327 38.91045564 -77.03551276
# Latitude and longitude count value -  33
# Source and destination pair -  38.85280397 -76.97014327 38.91053861 -77.02451482
# Latitude and longitude count value -  34
# Source and destination pair -  38.85280397 -76.97014327 38.91053945 -76.99087517
# Latitude and longitude count value -  35
# Source and destination pair -  38.85280397 -76.97014327 38.91071919 -76.98088989
# Latitude and longitude count value -  36
# Source and destination pair -  38.85280397 -76.97014327 38.91150838 -77.04595279
# Latitude and longitude count value -  37
# Source and destination pair -  38.85280397 -76.97014327 38.91161652 -76.96380558
# Latitude and longitude count value -  38
# Source and destination pair -  38.85280397 -76.97014327 38.91169876 -77.03078512
# Latitude and longitude count value -  39
# Source and destination pair -  38.85280397 -76.97014327 38.91194732 -77.00240612
# Latitude and longitude count value -  40
# Source and destination pair -  38.85280397 -76.97014327 38.91207602 -77.01922267
# Latitude and longitude count value -  41
# Source and destination pair -  38.85280397 -76.97014327 38.91222046 -77.04229031
# Latitude and longitude count value -  42
# Source and destination pair -  38.85280397 -76.97014327 38.92486859 -76.99087275
# Latitude and longitude count value -  43
# Source and destination pair -  38.85280397 -76.97014327 38.92490574 -77.03435005
# Latitude and longitude count value -  44
# Source and destination pair -  38.85280397 -76.97014327 38.92547711 -77.02483145
# Latitude and longitude count value -  45
# Source and destination pair -  38.85280397 -76.97014327 38.92801313 -77.05026843
# Latitude and longitude count value -  46
# Source and destination pair -  38.85280397 -76.97014327 38.92926801 -76.97090672
# Latitude and longitude count value -  47
# Source and destination pair -  38.85280397 -76.97014327 38.92930484 -76.99951564
# Latitude and longitude count value -  48
# Source and destination pair -  38.85280397 -76.97014327 38.93051785 -77.03768557
# Latitude and longitude count value -  49
# Source and destination pair -  38.85280397 -76.97014327 38.93080972 -77.03462047
# Latitude and longitude count value -  50
# Source and destination pair -  38.85280397 -76.97014327 38.931117 -77.02552977
# Latitude and longitude count value -  51
# Source and destination pair -  38.85280397 -76.97014327 38.93305058 -77.04034672
# Latitude and longitude count value -  52
# Source and destination pair -  38.85280397 -76.97014327 38.95804609 -77.06969787
# Latitude and longitude count value -  53
# Source and destination pair -  38.85280397 -76.97014327 38.95866356 -77.00377998
# Latitude and longitude count value -  54
# Source and destination pair -  38.85280397 -76.97014327 38.95933179 -77.08133247
# Latitude and longitude count value -  55
# Source and destination pair -  38.85280397 -76.97014327 38.96091005 -77.02366731
# Latitude and longitude count value -  56
# Source and destination pair -  38.85280397 -76.97014327 38.96282848 -77.07706425
# Latitude and longitude count value -  57
# Source and destination pair -  38.85280397 -76.97014327 38.96382436 -77.02387049
# Latitude and longitude count value -  58
# Source and destination pair -  38.85280397 -76.97014327 38.96611688 -77.0237762
# Latitude and longitude count value -  59
# Source and destination pair -  38.85280397 -76.97014327 38.96860273 -77.02366887
# Latitude and longitude count value -  60
# Source and destination pair -  38.85280397 -76.97014327 38.97105024 -77.01351589
# Latitude and longitude count value -  61
# Source and destination pair -  38.85280397 -76.97014327 38.97420739 -77.02985423
# Latitude and longitude count value -  62
# Source and destination pair -  38.85490654 -76.96256196 38.88129386 -76.99389976
# Latitude and longitude count value -  63
# Source and destination pair -  38.85490654 -76.96256196 38.88136087 -76.99886936
# Latitude and longitude count value -  64
# Source and destination pair -  38.85490654 -76.96256196 38.88178722 -76.98111151
# Latitude and longitude count value -  65
# Source and destination pair -  38.85490654 -76.96256196 38.88205036 -76.9858834
# Latitude and longitude count value -  66
# Source and destination pair -  38.85490654 -76.96256196 38.88207032 -77.02451512
# Latitude and longitude count value -  67
# Source and destination pair -  38.85490654 -76.96256196 38.88297987 -77.0033724
# Latitude and longitude count value -  68
# Source and destination pair -  38.85490654 -76.96256196 38.88344117 -77.01972757
# Latitude and longitude count value -  69
# Source and destination pair -  38.85490654 -76.96256196 38.88362626 -77.01377968
# Latitude and longitude count value -  70
# Source and destination pair -  38.85490654 -76.96256196 38.88572762 -77.00098029
# Latitude and longitude count value -  71
# Source and destination pair -  38.85490654 -76.96256196 38.88723589 -76.9932631
# Latitude and longitude count value -  72
# Source and destination pair -  38.85490654 -76.96256196 38.90253233 -77.0425942
# Latitude and longitude count value -  73
# Source and destination pair -  38.85490654 -76.96256196 38.90720628 -77.04183726
# Latitude and longitude count value -  74
# Source and destination pair -  38.85490654 -76.96256196 38.90830019 -77.05419866
# Latitude and longitude count value -  75
# Source and destination pair -  38.85490654 -76.96256196 38.90843889 -77.04771991
# Latitude and longitude count value -  76
# Source and destination pair -  38.85490654 -76.96256196 38.90855158 -77.03902816
# Latitude and longitude count value -  77
# Source and destination pair -  38.86527694 -76.98731555 38.90069992 -77.04713527
# Latitude and longitude count value -  78
# Source and destination pair -  38.86527694 -76.98731555 38.9010211 -77.05171998
# Latitude and longitude count value -  79
# Source and destination pair -  38.86527694 -76.98731555 38.90217222 -77.02994423
# Latitude and longitude count value -  80
# Source and destination pair -  38.87935377 -77.00423232 38.90045743 -77.01456899
# Latitude and longitude count value -  81
# Source and destination pair -  38.87935377 -77.00423232 38.90069992 -77.04713527
# Latitude and longitude count value -  82
# Source and destination pair -  38.87935377 -77.00423232 38.90180875 -76.99032054
# Latitude and longitude count value -  83
# Source and destination pair -  38.87935377 -77.00423232 38.90217222 -77.02994423
# Latitude and longitude count value -  84
# Source and destination pair -  38.87935377 -77.00423232 38.90253233 -77.0425942
# Latitude and longitude count value -  85
# Source and destination pair -  38.87935377 -77.00423232 38.9033784 -77.0041467
# Latitude and longitude count value -  86
# Source and destination pair -  38.87935377 -77.00423232 38.90385206 -77.03468821
# Latitude and longitude count value -  87
# Source and destination pair -  38.87935377 -77.00423232 38.9041102 -77.07111089
# Latitude and longitude count value -  88
# Source and destination pair -  38.87935377 -77.00423232 38.90492176 -77.04897729
# Latitude and longitude count value -  89
# Source and destination pair -  38.87935377 -77.00423232 38.90587351 -77.02044541
# Latitude and longitude count value -  90
# Source and destination pair -  38.87935377 -77.00423232 38.90643619 -77.05232668
# Latitude and longitude count value -  91
# Source and destination pair -  38.87935377 -77.00423232 38.90644373 -77.02832918
# Latitude and longitude count value -  92
# Source and destination pair -  38.87935377 -77.00423232 38.91222046 -77.04229031
# Latitude and longitude count value -  93
# Source and destination pair -  38.87935377 -77.00423232 38.91266636 -77.00635363
# Latitude and longitude count value -  94
# Source and destination pair -  38.87935377 -77.00423232 38.91433016 -77.06071162
# Latitude and longitude count value -  95
# Source and destination pair -  38.87935377 -77.00423232 38.91552654 -77.0269825
# Latitude and longitude count value -  96
# Source and destination pair -  38.87935377 -77.00423232 38.91615877 -77.04000231
# Latitude and longitude count value -  97
# Source and destination pair -  38.87935377 -77.00423232 38.9165433 -77.0374758
# Latitude and longitude count value -  98
# Source and destination pair -  38.87935377 -77.00423232 38.91662461 -77.04494504
# Latitude and longitude count value -  99
# Source and destination pair -  38.87935377 -77.00423232 38.91663604 -77.07720376
# Latitude and longitude count value -  100
# Source and destination pair -  38.87935377 -77.00423232 38.91706039 -77.0712757
# Latitude and longitude count value -  101
# Source and destination pair -  38.87935377 -77.00423232 38.91748831 -76.99035048
# Latitude and longitude count value -  102
# Source and destination pair -  38.87935377 -77.00423232 38.93467316 -77.01049834
# Latitude and longitude count value -  103
# Source and destination pair -  38.87935377 -77.00423232 38.93633412 -77.07528733
# Latitude and longitude count value -  104
# Source and destination pair -  38.87935377 -77.00423232 38.93809269 -77.00138814
# Latitude and longitude count value -  105
# Source and destination pair -  38.87935377 -77.00423232 38.93848882 -77.09331826
# Latitude and longitude count value -  106
# Source and destination pair -  38.87935377 -77.00423232 38.93963486 -77.07829574
# Latitude and longitude count value -  107
# Source and destination pair -  38.87935377 -77.00423232 38.94025071 -77.02729689
# Latitude and longitude count value -  108
# Source and destination pair -  38.87935377 -77.00423232 38.94145238 -77.10386152
# Latitude and longitude count value -  109
# Source and destination pair -  38.87935377 -77.00423232 38.9442133 -77.0079046
# Latitude and longitude count value -  110
# Source and destination pair -  38.87935377 -77.00423232 38.95240791 -77.00289174
# Latitude and longitude count value -  111
# Source and destination pair -  38.87935377 -77.00423232 38.95866356 -77.00377998
# Latitude and longitude count value -  112
# Source and destination pair -  38.88023959 -76.98728308 38.87786225 -77.03437325
# Latitude and longitude count value -  113
# Source and destination pair -  38.88023959 -76.98728308 38.87813611 -76.93075829
# Latitude and longitude count value -  114
# Source and destination pair -  38.88023959 -76.98728308 38.87935377 -77.00423232
# Latitude and longitude count value -  115
# Source and destination pair -  38.88023959 -76.98728308 38.88023959 -76.98728308
# Latitude and longitude count value -  116
# Source and destination pair -  38.88023959 -76.98728308 38.88129386 -76.99389976
# Latitude and longitude count value -  117
# Source and destination pair -  38.88023959 -76.98728308 38.88136087 -76.99886936
# Latitude and longitude count value -  118
# Source and destination pair -  38.88023959 -76.98728308 38.88178722 -76.98111151
# Latitude and longitude count value -  119
# Source and destination pair -  38.88023959 -76.98728308 38.88205036 -76.9858834
# Latitude and longitude count value -  120
# Source and destination pair -  38.88023959 -76.98728308 38.88207032 -77.02451512
# Latitude and longitude count value -  121
# Source and destination pair -  38.88023959 -76.98728308 38.88297987 -77.0033724
# Latitude and longitude count value -  122
# Source and destination pair -  38.88023959 -76.98728308 38.90045743 -77.01456899
# Latitude and longitude count value -  123
# Source and destination pair -  38.88023959 -76.98728308 38.90065602 -76.97852368
# Latitude and longitude count value -  124
# Source and destination pair -  38.88023959 -76.98728308 38.90069992 -77.04713527
# Latitude and longitude count value -  125
# Source and destination pair -  38.88023959 -76.98728308 38.90217222 -77.02994423
# Latitude and longitude count value -  126
# Source and destination pair -  38.88023959 -76.98728308 38.9022102 -76.95448698
# Latitude and longitude count value -  127
# Source and destination pair -  38.88023959 -76.98728308 38.90253233 -77.0425942
# Latitude and longitude count value -  128
# Source and destination pair -  38.88023959 -76.98728308 38.9033784 -77.0041467
# Latitude and longitude count value -  129
# Source and destination pair -  38.88023959 -76.98728308 38.90385076 -76.9793838
# Latitude and longitude count value -  130
# Source and destination pair -  38.88023959 -76.98728308 38.90385206 -77.03468821
# Latitude and longitude count value -  131
# Source and destination pair -  38.88023959 -76.98728308 38.9041102 -77.07111089
# Latitude and longitude count value -  132
# Source and destination pair -  38.88023959 -76.98728308 38.91662461 -77.04494504
# Latitude and longitude count value -  133
# Source and destination pair -  38.88023959 -76.98728308 38.91663604 -77.07720376
# Latitude and longitude count value -  134
# Source and destination pair -  38.88023959 -76.98728308 38.91706039 -77.0712757
# Latitude and longitude count value -  135
# Source and destination pair -  38.88023959 -76.98728308 38.91877681 -77.02814588
# Latitude and longitude count value -  136
# Source and destination pair -  38.88023959 -76.98728308 38.92087064 -77.07984909
# Latitude and longitude count value -  137
# Source and destination pair -  38.88023959 -76.98728308 38.92133926 -77.01773285
# Latitude and longitude count value -  138
# Source and destination pair -  38.88023959 -76.98728308 38.92166117 -77.03981267
# Latitude and longitude count value -  139
# Source and destination pair -  38.88023959 -76.98728308 38.92209241 -77.06361718
# Latitude and longitude count value -  140
# Source and destination pair -  38.88023959 -76.98728308 38.92221251 -77.0544705
# Latitude and longitude count value -  141
# Source and destination pair -  38.88023959 -76.98728308 38.92731855 -77.06984356
# Latitude and longitude count value -  142
# Source and destination pair -  38.88023959 -76.98728308 38.94506487 -77.03458049
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-e6be7449a169> in <module>()
#      25     }
#      26
# ---> 27     r = requests.get('https://maps.googleapis.com/maps/api/directions/json?', params=params, headers=headers)
#      28
#      29     if len(r.json()['routes']) != 0:
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     374                     decode_content=False,
#     375                     retries=self.max_retries,
# --> 376                     timeout=timeout
#     377                 )
#     378
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     557             httplib_response = self._make_request(conn, method, url,
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#     561             # If we're going to release the connection in ``finally:``, then
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     374         try:
#     375             try:  # Python 2.7, use buffering of HTTP responses
# --> 376                 httplib_response = conn.getresponse(buffering=True)
#     377             except TypeError:  # Python 2.6 and older
#     378                 httplib_response = conn.getresponse()
#
# /Users/kruthika/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /Users/kruthika/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /Users/kruthika/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /Users/kruthika/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/kruthika/anaconda/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     732                     "non-zero flags not allowed in calls to recv() on %s" %
#     733                     self.__class__)
# --> 734             return self.read(buflen)
#     735         else:
#     736             return self._sock.recv(buflen, flags)
#
# /Users/kruthika/anaconda/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     619                 v = self._sslobj.read(len, buffer)
#     620             else:
# --> 621                 v = self._sslobj.read(len or 1024)
#     622             return v
#     623         except SSLError as x:
#
# KeyboardInterrupt:
