# %%
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
import sqlite3 as lite
import numpy as np

from sqlalchemy import create_engine
sqlite_file = 'sqlite://///Users/Kruthika/Projects/DDL/04-team3/census_v2.db'
engine = create_engine(sqlite_file)
from pandas.io import sql
home_work=pd.read_sql_table('home_work', engine)
#df=home_work.iloc[751:]
df=home_work

from time import sleep

count=0
for index, row in df.iterrows():
    #print row['home_lat'], row['home_lon'], row['work_lat'], row['work_lon']
    source_lat = row['home_lat']
    source_lon = row['home_lon']
    dest_lat= row['work_lat']
    dest_lon= row['work_lon']
    
    headers = {
        'key':'AIzaSyAUlQnrcpJkb8u6xmL2UuHyPFD5CxWdLPo'
    }
    
    params = {
    # Request parameters
    #'origin': source_lat+','+source_lon,
    #'destination':dest_lat+','+dest_lon,
    'origin': dest_lat+','+dest_lon,
    'destination':source_lat+','+source_lon,
    'alternatives':'false',
    'mode':'car',
    'traffic_model':'optimistic',
    'departure_time':'now'
    }
    
    r = requests.get('https://maps.googleapis.com/maps/api/directions/json?', params=params, headers=headers)
    
    if len(r.json()['routes']) != 0:
        if len(json_normalize(r.json()['routes'][0]['legs'][0])) != 0:
            df=json_normalize(r.json()['routes'][0]['legs'][0])
            df1=df.drop(['steps','traffic_speed_entry','via_waypoint'], axis=1)
            df1['unique_id']=source_lat+'_'+source_lon+'_'+dest_lat+'_'+dest_lon


            df1.to_sql('car_info_hw', engine,if_exists='append')
        else:
            continue
    else:
        continue
    count += 1
    print 'Latitude and longitude count value - ',count
    print 'Source and destination pair - ', source_lat, source_lon, dest_lat, dest_lon
    
print "Successful data collection!"
# Out:
# Latitude and longitude count value -  1
# Source and destination pair -  38.82670472 -77.00375738 38.9041102 -77.07111089
# Latitude and longitude count value -  2
# Source and destination pair -  38.82670472 -77.00375738 38.90452631 -77.01519888
# Latitude and longitude count value -  3
# Source and destination pair -  38.82670472 -77.00375738 38.90489618 -77.02825547
# Latitude and longitude count value -  4
# Source and destination pair -  38.82670472 -77.00375738 38.90492176 -77.04897729
# Latitude and longitude count value -  5
# Source and destination pair -  38.82670472 -77.00375738 38.90645843 -77.06592563
# Latitude and longitude count value -  6
# Source and destination pair -  38.82670472 -77.00375738 38.90720628 -77.04183726
# Latitude and longitude count value -  7
# Source and destination pair -  38.82670472 -77.00375738 38.91929976 -77.01350976
# Latitude and longitude count value -  8
# Source and destination pair -  38.82670472 -77.00375738 38.92133926 -77.01773285
# Latitude and longitude count value -  9
# Source and destination pair -  38.82670472 -77.00375738 38.92166117 -77.03981267
# Latitude and longitude count value -  10
# Source and destination pair -  38.82670472 -77.00375738 38.92209241 -77.06361718
# Latitude and longitude count value -  11
# Source and destination pair -  38.82670472 -77.00375738 38.92221251 -77.0544705
# Latitude and longitude count value -  12
# Source and destination pair -  38.82670472 -77.00375738 38.92264653 -76.9977218
# Latitude and longitude count value -  13
# Source and destination pair -  38.82670472 -77.00375738 38.95739565 -77.08688934
# Latitude and longitude count value -  14
# Source and destination pair -  38.82670472 -77.00375738 38.95804609 -77.06969787
# Latitude and longitude count value -  15
# Source and destination pair -  38.82670472 -77.00375738 38.9589056 -77.02443437
# Latitude and longitude count value -  16
# Source and destination pair -  38.82670472 -77.00375738 38.95933179 -77.08133247
# Latitude and longitude count value -  17
# Source and destination pair -  38.82670472 -77.00375738 38.95951414 -77.03139867
# Latitude and longitude count value -  18
# Source and destination pair -  38.82670472 -77.00375738 38.96382436 -77.02387049
# Latitude and longitude count value -  19
# Source and destination pair -  38.82797649 -77.0066917 38.89538647 -77.00081224
# Latitude and longitude count value -  20
# Source and destination pair -  38.82797649 -77.0066917 38.89612766 -76.99667972
# Latitude and longitude count value -  21
# Source and destination pair -  38.82797649 -77.0066917 38.89625783 -77.0146534
# Latitude and longitude count value -  22
# Source and destination pair -  38.82797649 -77.0066917 38.89627629 -77.04292119
# Latitude and longitude count value -  23
# Source and destination pair -  38.82797649 -77.0066917 38.89729855 -77.05158057
# Latitude and longitude count value -  24
# Source and destination pair -  38.82797649 -77.0066917 38.89743112 -77.02045237
# Latitude and longitude count value -  25
# Source and destination pair -  38.82797649 -77.0066917 38.91662461 -77.04494504
# Latitude and longitude count value -  26
# Source and destination pair -  38.82797649 -77.0066917 38.91748831 -76.99035048
# Latitude and longitude count value -  27
# Source and destination pair -  38.82797649 -77.0066917 38.91793499 -77.04312304
# Latitude and longitude count value -  28
# Source and destination pair -  38.82797649 -77.0066917 38.91811139 -77.03422762
# Latitude and longitude count value -  29
# Source and destination pair -  38.82797649 -77.0066917 38.91877681 -77.02814588
# Latitude and longitude count value -  30
# Source and destination pair -  38.82797649 -77.0066917 38.91973122 -77.03900634
# Latitude and longitude count value -  31
# Source and destination pair -  38.82797649 -77.0066917 38.95933179 -77.08133247
# Latitude and longitude count value -  32
# Source and destination pair -  38.82797649 -77.0066917 38.95951414 -77.03139867
# Latitude and longitude count value -  33
# Source and destination pair -  38.82797649 -77.0066917 38.96282848 -77.07706425
# Latitude and longitude count value -  34
# Source and destination pair -  38.82797649 -77.0066917 38.98059882 -77.02917435
# Latitude and longitude count value -  35
# Source and destination pair -  38.82797649 -77.0066917 38.98670216 -77.0321483
# Latitude and longitude count value -  36
# Source and destination pair -  38.83010611 -76.99690524 38.8096324 -77.02283643
# Latitude and longitude count value -  37
# Source and destination pair -  38.83010611 -76.99690524 38.89229315 -77.00206563
# Latitude and longitude count value -  38
# Source and destination pair -  38.83010611 -76.99690524 38.89279738 -76.91401929
# Latitude and longitude count value -  39
# Source and destination pair -  38.83010611 -76.99690524 38.89612766 -76.99667972
# Latitude and longitude count value -  40
# Source and destination pair -  38.83010611 -76.99690524 38.89622614 -76.97385777
# Latitude and longitude count value -  41
# Source and destination pair -  38.83010611 -76.99690524 38.89625783 -77.0146534
# Latitude and longitude count value -  42
# Source and destination pair -  38.83010611 -76.99690524 38.89743112 -77.02045237
# Latitude and longitude count value -  43
# Source and destination pair -  38.83010611 -76.99690524 38.90643619 -77.05232668
# Latitude and longitude count value -  44
# Source and destination pair -  38.83010611 -76.99690524 38.90645843 -77.06592563
# Latitude and longitude count value -  45
# Source and destination pair -  38.83010611 -76.99690524 38.90720628 -77.04183726
# Latitude and longitude count value -  46
# Source and destination pair -  38.83010611 -76.99690524 38.90843889 -77.04771991
# Latitude and longitude count value -  47
# Source and destination pair -  38.83010611 -76.99690524 38.90852283 -77.04542707
# Latitude and longitude count value -  48
# Source and destination pair -  38.83010611 -76.99690524 38.90931566 -77.07455457
# Latitude and longitude count value -  49
# Source and destination pair -  38.83010611 -76.99690524 38.93305058 -77.04034672
# Latitude and longitude count value -  50
# Source and destination pair -  38.83010611 -76.99690524 38.93363754 -77.06177171
# Latitude and longitude count value -  51
# Source and destination pair -  38.83010611 -76.99690524 38.93373104 -77.03125977
# Latitude and longitude count value -  52
# Source and destination pair -  38.83010611 -76.99690524 38.93467316 -77.01049834
# Latitude and longitude count value -  53
# Source and destination pair -  38.83010611 -76.99690524 38.93703188 -77.02699651
# Latitude and longitude count value -  54
# Source and destination pair -  38.83010611 -76.99690524 38.98059882 -77.02917435
# Latitude and longitude count value -  55
# Source and destination pair -  38.83061467 -76.99181518 38.8096324 -77.02283643
# Latitude and longitude count value -  56
# Source and destination pair -  38.83061467 -76.99181518 38.82572535 -77.01193256
# Latitude and longitude count value -  57
# Source and destination pair -  38.83061467 -76.99181518 38.84042391 -76.9833259
# Latitude and longitude count value -  58
# Source and destination pair -  38.83061467 -76.99181518 38.84839225 -76.97380687
# Latitude and longitude count value -  59
# Source and destination pair -  38.83061467 -76.99181518 38.85157227 -76.99759371
# Latitude and longitude count value -  60
# Source and destination pair -  38.83061467 -76.99181518 38.89743112 -77.02045237
# Latitude and longitude count value -  61
# Source and destination pair -  38.83061467 -76.99181518 38.89755634 -76.94484528
# Latitude and longitude count value -  62
# Source and destination pair -  38.83061467 -76.99181518 38.897956 -76.99329252
# Latitude and longitude count value -  63
# Source and destination pair -  38.83061467 -76.99181518 38.89801164 -77.02717393
# Latitude and longitude count value -  64
# Source and destination pair -  38.83061467 -76.99181518 38.89876337 -77.00097333
# Latitude and longitude count value -  65
# Source and destination pair -  38.83061467 -76.99181518 38.91161652 -76.96380558
# Latitude and longitude count value -  66
# Source and destination pair -  38.83061467 -76.99181518 38.91194732 -77.00240612
# Latitude and longitude count value -  67
# Source and destination pair -  38.83061467 -76.99181518 38.91207602 -77.01922267
# Latitude and longitude count value -  68
# Source and destination pair -  38.83061467 -76.99181518 38.91262779 -77.01126857
# Latitude and longitude count value -  69
# Source and destination pair -  38.83061467 -76.99181518 38.91266636 -77.00635363
# Latitude and longitude count value -  70
# Source and destination pair -  38.83061467 -76.99181518 38.96860273 -77.02366887
# Latitude and longitude count value -  71
# Source and destination pair -  38.83061467 -76.99181518 38.98059882 -77.02917435
# Latitude and longitude count value -  72
# Source and destination pair -  38.83061467 -76.99181518 38.98670216 -77.0321483
# Latitude and longitude count value -  73
# Source and destination pair -  38.83167957 -76.99563337 38.82572535 -77.01193256
# Latitude and longitude count value -  74
# Source and destination pair -  38.83167957 -76.99563337 38.82626132 -77.00047489
# Latitude and longitude count value -  75
# Source and destination pair -  38.83167957 -76.99563337 38.82641682 -76.99597908
# Latitude and longitude count value -  76
# Source and destination pair -  38.83167957 -76.99563337 38.90065602 -76.97852368
# Latitude and longitude count value -  77
# Source and destination pair -  38.83167957 -76.99563337 38.90069992 -77.04713527
# Latitude and longitude count value -  78
# Source and destination pair -  38.83167957 -76.99563337 38.90119687 -76.93658875
# Latitude and longitude count value -  79
# Source and destination pair -  38.83167957 -76.99563337 38.90217222 -77.02994423
# Latitude and longitude count value -  80
# Source and destination pair -  38.83167957 -76.99563337 38.90253233 -77.0425942
# Latitude and longitude count value -  81
# Source and destination pair -  38.83167957 -76.99563337 38.9033784 -77.0041467
# Latitude and longitude count value -  82
# Source and destination pair -  38.83167957 -76.99563337 38.95739565 -77.08688934
# Latitude and longitude count value -  83
# Source and destination pair -  38.83167957 -76.99563337 38.96282848 -77.07706425
# Latitude and longitude count value -  84
# Source and destination pair -  38.83167957 -76.99563337 38.98059882 -77.02917435
# Latitude and longitude count value -  85
# Source and destination pair -  38.83317015 -77.01192444 38.8096324 -77.02283643
# Latitude and longitude count value -  86
# Source and destination pair -  38.83317015 -77.01192444 38.82572535 -77.01193256
# Latitude and longitude count value -  87
# Source and destination pair -  38.83317015 -77.01192444 38.83317015 -77.01192444
# Latitude and longitude count value -  88
# Source and destination pair -  38.83317015 -77.01192444 38.897956 -76.99329252
# Latitude and longitude count value -  89
# Source and destination pair -  38.83317015 -77.01192444 38.89801164 -77.02717393
# Latitude and longitude count value -  90
# Source and destination pair -  38.83317015 -77.01192444 38.89817395 -76.98159904
# Latitude and longitude count value -  91
# Source and destination pair -  38.83317015 -77.01192444 38.89874923 -77.05467122
# Latitude and longitude count value -  92
# Source and destination pair -  38.83317015 -77.01192444 38.89964623 -77.0618145
# Latitude and longitude count value -  93
# Source and destination pair -  38.83317015 -77.01192444 38.90045743 -77.01456899
# Latitude and longitude count value -  94
# Source and destination pair -  38.83317015 -77.01192444 38.91748831 -76.99035048
# Latitude and longitude count value -  95
# Source and destination pair -  38.83317015 -77.01192444 38.91877681 -77.02814588
# Latitude and longitude count value -  96
# Source and destination pair -  38.83317015 -77.01192444 38.92209241 -77.06361718
# Latitude and longitude count value -  97
# Source and destination pair -  38.83317015 -77.01192444 38.92221251 -77.0544705
# Latitude and longitude count value -  98
# Source and destination pair -  38.83317015 -77.01192444 38.92264653 -76.9977218
# Latitude and longitude count value -  99
# Source and destination pair -  38.83317015 -77.01192444 38.92444798 -76.96461733
# Latitude and longitude count value -  100
# Source and destination pair -  38.83343321 -77.00392458 38.87786225 -77.03437325
# Latitude and longitude count value -  101
# Source and destination pair -  38.83343321 -77.00392458 38.87788045 -76.96827466
# Latitude and longitude count value -  102
# Source and destination pair -  38.83343321 -77.00392458 38.88023959 -76.98728308
# Latitude and longitude count value -  103
# Source and destination pair -  38.83343321 -77.00392458 38.88129386 -76.99389976
# Latitude and longitude count value -  104
# Source and destination pair -  38.83343321 -77.00392458 38.88205036 -76.9858834
# Latitude and longitude count value -  105
# Source and destination pair -  38.83343321 -77.00392458 38.88207032 -77.02451512
# Latitude and longitude count value -  106
# Source and destination pair -  38.83343321 -77.00392458 38.91454576 -77.04372464
# Latitude and longitude count value -  107
# Source and destination pair -  38.83343321 -77.00392458 38.91811139 -77.03422762
# Latitude and longitude count value -  108
# Source and destination pair -  38.83343321 -77.00392458 38.91877681 -77.02814588
# Latitude and longitude count value -  109
# Source and destination pair -  38.83343321 -77.00392458 38.92209241 -77.06361718
# Latitude and longitude count value -  110
# Source and destination pair -  38.83343321 -77.00392458 38.92486859 -76.99087275
# Latitude and longitude count value -  111
# Source and destination pair -  38.83343321 -77.00392458 38.92801313 -77.05026843
# Latitude and longitude count value -  112
# Source and destination pair -  38.83343321 -77.00392458 38.95627562 -77.02605595
# Latitude and longitude count value -  113
# Source and destination pair -  38.83343321 -77.00392458 38.95933179 -77.08133247
# Latitude and longitude count value -  114
# Source and destination pair -  38.83343321 -77.00392458 38.96860273 -77.02366887
# Latitude and longitude count value -  115
# Source and destination pair -  38.83343321 -77.00392458 38.97105024 -77.01351589
# Latitude and longitude count value -  116
# Source and destination pair -  38.83343321 -77.00392458 38.9760153 -77.02344534
# Latitude and longitude count value -  117
# Source and destination pair -  38.83343321 -77.00392458 38.98059882 -77.02917435
# Latitude and longitude count value -  118
# Source and destination pair -  38.83404996 -76.99655193 38.8874763 -76.99880141
# Latitude and longitude count value -  119
# Source and destination pair -  38.83404996 -76.99655193 38.8875746 -76.97151957
# Latitude and longitude count value -  120
# Source and destination pair -  38.83404996 -76.99655193 38.89128932 -76.99678103
# Latitude and longitude count value -  121
# Source and destination pair -  38.83404996 -76.99655193 38.89221821 -76.94955368
# Latitude and longitude count value -  122
# Source and destination pair -  38.83404996 -76.99655193 38.89292805 -76.95902884
# Latitude and longitude count value -  123
# Source and destination pair -  38.83404996 -76.99655193 38.89605239 -76.98694455
# Latitude and longitude count value -  124
# Source and destination pair -  38.83404996 -76.99655193 38.91053945 -76.99087517
# Latitude and longitude count value -  125
# Source and destination pair -  38.83404996 -76.99655193 38.91150838 -77.04595279
# Latitude and longitude count value -  126
# Source and destination pair -  38.83404996 -76.99655193 38.91161652 -76.96380558
# Latitude and longitude count value -  127
# Source and destination pair -  38.83404996 -76.99655193 38.91368052 -77.0686347
# Latitude and longitude count value -  128
# Source and destination pair -  38.83404996 -76.99655193 38.91548151 -77.0341528
# Latitude and longitude count value -  129
# Source and destination pair -  38.83404996 -76.99655193 38.91552654 -77.0269825
# Latitude and longitude count value -  130
# Source and destination pair -  38.83404996 -76.99655193 38.93848882 -77.09331826
# Latitude and longitude count value -  131
# Source and destination pair -  38.83404996 -76.99655193 38.93944185 -76.98303703
# Latitude and longitude count value -  132
# Source and destination pair -  38.83404996 -76.99655193 38.94145238 -77.10386152
# Latitude and longitude count value -  133
# Source and destination pair -  38.83404996 -76.99655193 38.9419686 -77.02245854
# Latitude and longitude count value -  134
# Source and destination pair -  38.83404996 -76.99655193 38.94354289 -76.99391516
# Latitude and longitude count value -  135
# Source and destination pair -  38.83404996 -76.99655193 38.94372863 -77.07003837
# Latitude and longitude count value -  136
# Source and destination pair -  38.83479611 -77.00524572 38.82572535 -77.01193256
# Latitude and longitude count value -  137
# Source and destination pair -  38.83479611 -77.00524572 38.82641682 -76.99597908
# Latitude and longitude count value -  138
# Source and destination pair -  38.83479611 -77.00524572 38.83404996 -76.99655193
# Latitude and longitude count value -  139
# Source and destination pair -  38.83479611 -77.00524572 38.83910769 -76.99690024
# Latitude and longitude count value -  140
# Source and destination pair -  38.83479611 -77.00524572 38.84042391 -76.9833259
# Latitude and longitude count value -  141
# Source and destination pair -  38.83479611 -77.00524572 38.84186464 -77.00192877
# Latitude and longitude count value -  142
# Source and destination pair -  38.83479611 -77.00524572 38.89874923 -77.05467122
# Latitude and longitude count value -  143
# Source and destination pair -  38.83479611 -77.00524572 38.90045743 -77.01456899
# Latitude and longitude count value -  144
# Source and destination pair -  38.83479611 -77.00524572 38.90065602 -76.97852368
# Latitude and longitude count value -  145
# Source and destination pair -  38.83479611 -77.00524572 38.90069992 -77.04713527
# Latitude and longitude count value -  146
# Source and destination pair -  38.83479611 -77.00524572 38.90217222 -77.02994423
# Latitude and longitude count value -  147
# Source and destination pair -  38.83479611 -77.00524572 38.9022102 -76.95448698
# Latitude and longitude count value -  148
# Source and destination pair -  38.83479611 -77.00524572 38.91266636 -77.00635363
# Latitude and longitude count value -  149
# Source and destination pair -  38.83479611 -77.00524572 38.91454576 -77.04372464
# Latitude and longitude count value -  150
# Source and destination pair -  38.83479611 -77.00524572 38.91748831 -76.99035048
# Latitude and longitude count value -  151
# Source and destination pair -  38.83479611 -77.00524572 38.91811139 -77.03422762
# Latitude and longitude count value -  152
# Source and destination pair -  38.83479611 -77.00524572 38.92133926 -77.01773285
# Latitude and longitude count value -  153
# Source and destination pair -  38.83479611 -77.00524572 38.92209241 -77.06361718
# Latitude and longitude count value -  154
# Source and destination pair -  38.83493209 -76.98921118 38.84042391 -76.9833259
# Latitude and longitude count value -  155
# Source and destination pair -  38.83493209 -76.98921118 38.84241783 -77.02307164
# Latitude and longitude count value -  156
# Source and destination pair -  38.83493209 -76.98921118 38.85157227 -76.99759371
# Latitude and longitude count value -  157
# Source and destination pair -  38.83493209 -76.98921118 38.85490654 -76.96256196
# Latitude and longitude count value -  158
# Source and destination pair -  38.83493209 -76.98921118 38.85524974 -76.96668369
# Latitude and longitude count value -  159
# Source and destination pair -  38.83493209 -76.98921118 38.8874763 -76.99880141
# Latitude and longitude count value -  160
# Source and destination pair -  38.83493209 -76.98921118 38.89221821 -76.94955368
# Latitude and longitude count value -  161
# Source and destination pair -  38.83493209 -76.98921118 38.89279738 -76.91401929
# Latitude and longitude count value -  162
# Source and destination pair -  38.83493209 -76.98921118 38.89339859 -76.99260146
# Latitude and longitude count value -  163
# Source and destination pair -  38.83493209 -76.98921118 38.89538647 -77.00081224
# Latitude and longitude count value -  164
# Source and destination pair -  38.83493209 -76.98921118 38.89612766 -76.99667972
# Latitude and longitude count value -  165
# Source and destination pair -  38.83493209 -76.98921118 38.9041102 -77.07111089
# Latitude and longitude count value -  166
# Source and destination pair -  38.83493209 -76.98921118 38.90452631 -77.01519888
# Latitude and longitude count value -  167
# Source and destination pair -  38.83493209 -76.98921118 38.90492176 -77.04897729
# Latitude and longitude count value -  168
# Source and destination pair -  38.83493209 -76.98921118 38.90587351 -77.02044541
# Latitude and longitude count value -  169
# Source and destination pair -  38.83493209 -76.98921118 38.90643619 -77.05232668
# Latitude and longitude count value -  170
# Source and destination pair -  38.83493209 -76.98921118 38.90645843 -77.06592563
# Latitude and longitude count value -  171
# Source and destination pair -  38.83493209 -76.98921118 38.92052368 -77.02428515
# Latitude and longitude count value -  172
# Source and destination pair -  38.83493209 -76.98921118 38.92133926 -77.01773285
# Latitude and longitude count value -  173
# Source and destination pair -  38.83493209 -76.98921118 38.92166117 -77.03981267
# Latitude and longitude count value -  174
# Source and destination pair -  38.83493209 -76.98921118 38.92209241 -77.06361718
# Latitude and longitude count value -  175
# Source and destination pair -  38.83493209 -76.98921118 38.92221251 -77.0544705
# Latitude and longitude count value -  176
# Source and destination pair -  38.83493209 -76.98921118 38.92264653 -76.9977218
# Latitude and longitude count value -  177
# Source and destination pair -  38.83493209 -76.98921118 38.93249434 -76.98198704
# Latitude and longitude count value -  178
# Source and destination pair -  38.83493209 -76.98921118 38.93324072 -76.97641392
# Latitude and longitude count value -  179
# Source and destination pair -  38.83493209 -76.98921118 38.93467316 -77.01049834
# Latitude and longitude count value -  180
# Source and destination pair -  38.83493209 -76.98921118 38.93633412 -77.07528733
# Latitude and longitude count value -  181
# Source and destination pair -  38.83493209 -76.98921118 38.93703188 -77.02699651
# Latitude and longitude count value -  182
# Source and destination pair -  38.83493209 -76.98921118 38.945163 -77.06020383
# Latitude and longitude count value -  183
# Source and destination pair -  38.83493209 -76.98921118 38.94985829 -77.04211055
# Latitude and longitude count value -  184
# Source and destination pair -  38.83493209 -76.98921118 38.95119374 -77.08447865
# Latitude and longitude count value -  185
# Source and destination pair -  38.83493209 -76.98921118 38.952555 -77.07627268
# Latitude and longitude count value -  186
# Source and destination pair -  38.83493209 -76.98921118 38.95627562 -77.02605595
# Latitude and longitude count value -  187
# Source and destination pair -  38.83881445 -77.00305098 38.8096324 -77.02283643
# Latitude and longitude count value -  188
# Source and destination pair -  38.83881445 -77.00305098 38.82572535 -77.01193256
# Latitude and longitude count value -  189
# Source and destination pair -  38.83881445 -77.00305098 38.82641682 -76.99597908
# Latitude and longitude count value -  190
# Source and destination pair -  38.83881445 -77.00305098 38.83343321 -77.00392458
# Latitude and longitude count value -  191
# Source and destination pair -  38.83881445 -77.00305098 38.83404996 -76.99655193
# Latitude and longitude count value -  192
# Source and destination pair -  38.83881445 -77.00305098 38.84186464 -77.00192877
# Latitude and longitude count value -  193
# Source and destination pair -  38.83881445 -77.00305098 38.90645843 -77.06592563
# Latitude and longitude count value -  194
# Source and destination pair -  38.83881445 -77.00305098 38.90720628 -77.04183726
# Latitude and longitude count value -  195
# Source and destination pair -  38.83881445 -77.00305098 38.90843889 -77.04771991
# Latitude and longitude count value -  196
# Source and destination pair -  38.83881445 -77.00305098 38.9091533 -77.01064917
# Latitude and longitude count value -  197
# Source and destination pair -  38.83881445 -77.00305098 38.91045564 -77.03551276
# Latitude and longitude count value -  198
# Source and destination pair -  38.83881445 -77.00305098 38.91053861 -77.02451482
# Latitude and longitude count value -  199
# Source and destination pair -  38.83910769 -76.99690024 38.82626132 -77.00047489
# Latitude and longitude count value -  200
# Source and destination pair -  38.83910769 -76.99690024 38.82641682 -76.99597908
# Latitude and longitude count value -  201
# Source and destination pair -  38.83910769 -76.99690024 38.83404996 -76.99655193
# Latitude and longitude count value -  202
# Source and destination pair -  38.83910769 -76.99690024 38.83910769 -76.99690024
# Latitude and longitude count value -  203
# Source and destination pair -  38.83910769 -76.99690024 38.83996392 -77.00067029
# Latitude and longitude count value -  204
# Source and destination pair -  38.83910769 -76.99690024 38.85157227 -76.99759371
# Latitude and longitude count value -  205
# Source and destination pair -  38.8573335 -76.99535535 38.89627629 -77.04292119
# Latitude and longitude count value -  206
# Source and destination pair -  38.8573335 -76.99535535 38.89743112 -77.02045237
# Latitude and longitude count value -  207
# Source and destination pair -  38.8573335 -76.99535535 38.89755634 -76.94484528
# Latitude and longitude count value -  208
# Source and destination pair -  38.8573335 -76.99535535 38.897956 -76.99329252
# Latitude and longitude count value -  209
# Source and destination pair -  38.8573335 -76.99535535 38.89801164 -77.02717393
# Latitude and longitude count value -  210
# Source and destination pair -  38.85936131 -76.96323218 38.91053945 -76.99087517
# Latitude and longitude count value -  211
# Source and destination pair -  38.85936131 -76.96323218 38.91161652 -76.96380558
# Latitude and longitude count value -  212
# Source and destination pair -  38.85936131 -76.96323218 38.91207602 -77.01922267
# Latitude and longitude count value -  213
# Source and destination pair -  38.85936131 -76.96323218 38.91454576 -77.04372464
# Latitude and longitude count value -  214
# Source and destination pair -  38.85936131 -76.96323218 38.91506889 -77.01149696
# Latitude and longitude count value -  215
# Source and destination pair -  38.85936131 -76.96323218 38.91748831 -76.99035048
# Latitude and longitude count value -  216
# Source and destination pair -  38.85936131 -76.96323218 38.91877681 -77.02814588
# Latitude and longitude count value -  217
# Source and destination pair -  38.85936131 -76.96323218 38.92133926 -77.01773285
# Latitude and longitude count value -  218
# Source and destination pair -  38.85936131 -76.96323218 38.93848882 -77.09331826
# Latitude and longitude count value -  219
# Source and destination pair -  38.85936131 -76.96323218 38.938492 -77.08215144
# Latitude and longitude count value -  220
# Source and destination pair -  38.85936131 -76.96323218 38.94354289 -76.99391516
# Latitude and longitude count value -  221
# Source and destination pair -  38.85936131 -76.96323218 38.95119374 -77.08447865
# Latitude and longitude count value -  222
# Source and destination pair -  38.85936131 -76.96323218 38.98059882 -77.02917435
# Latitude and longitude count value -  223
# Source and destination pair -  38.85980631 -76.98979257 38.8096324 -77.02283643
# Latitude and longitude count value -  224
# Source and destination pair -  38.85980631 -76.98979257 38.88535555 -76.98085023
# Latitude and longitude count value -  225
# Source and destination pair -  38.85980631 -76.98979257 38.88572762 -77.00098029
# Latitude and longitude count value -  226
# Source and destination pair -  38.85980631 -76.98979257 38.8874763 -76.99880141
# Latitude and longitude count value -  227
# Source and destination pair -  38.85980631 -76.98979257 38.8875746 -76.97151957
# Latitude and longitude count value -  228
# Source and destination pair -  38.85980631 -76.98979257 38.89221821 -76.94955368
# Latitude and longitude count value -  229
# Source and destination pair -  38.85980631 -76.98979257 38.89612766 -76.99667972
# Latitude and longitude count value -  230
# Source and destination pair -  38.85980631 -76.98979257 38.90843889 -77.04771991
# Latitude and longitude count value -  231
# Source and destination pair -  38.85980631 -76.98979257 38.90855158 -77.03902816
# Latitude and longitude count value -  232
# Source and destination pair -  38.85980631 -76.98979257 38.90923365 -77.06653954
# Latitude and longitude count value -  233
# Source and destination pair -  38.85980631 -76.98979257 38.90931566 -77.07455457
# Latitude and longitude count value -  234
# Source and destination pair -  38.85980631 -76.98979257 38.91053945 -76.99087517
# Latitude and longitude count value -  235
# Source and destination pair -  38.85980631 -76.98979257 38.91071919 -76.98088989
# Latitude and longitude count value -  236
# Source and destination pair -  38.85980631 -76.98979257 38.92930484 -76.99951564
# Latitude and longitude count value -  237
# Source and destination pair -  38.85980631 -76.98979257 38.93080972 -77.03462047
# Latitude and longitude count value -  238
# Source and destination pair -  38.85980631 -76.98979257 38.93100522 -76.99133987
# Latitude and longitude count value -  239
# Source and destination pair -  38.85980631 -76.98979257 38.931117 -77.02552977
# Latitude and longitude count value -  240
# Source and destination pair -  38.85980631 -76.98979257 38.93249434 -76.98198704
# Latitude and longitude count value -  241
# Source and destination pair -  38.85980631 -76.98979257 38.93305058 -77.04034672
# Latitude and longitude count value -  242
# Source and destination pair -  38.86120821 -76.97986921 38.8096324 -77.02283643
# Latitude and longitude count value -  243
# Source and destination pair -  38.86120821 -76.97986921 38.83881445 -77.00305098
# Latitude and longitude count value -  244
# Source and destination pair -  38.86120821 -76.97986921 38.84042391 -76.9833259
# Latitude and longitude count value -  245
# Source and destination pair -  38.86120821 -76.97986921 38.85157227 -76.99759371
# Latitude and longitude count value -  246
# Source and destination pair -  38.86120821 -76.97986921 38.85524974 -76.96668369
# Latitude and longitude count value -  247
# Source and destination pair -  38.86120821 -76.97986921 38.85919458 -76.97222365
# Latitude and longitude count value -  248
# Source and destination pair -  38.86120821 -76.97986921 38.8949206 -76.95610107
# Latitude and longitude count value -  249
# Source and destination pair -  38.86120821 -76.97986921 38.89538647 -77.00081224
# Latitude and longitude count value -  250
# Source and destination pair -  38.86120821 -76.97986921 38.89612766 -76.99667972
# Latitude and longitude count value -  251
# Source and destination pair -  38.86120821 -76.97986921 38.89625783 -77.0146534
# Latitude and longitude count value -  252
# Source and destination pair -  38.86120821 -76.97986921 38.89627629 -77.04292119
# Latitude and longitude count value -  253
# Source and destination pair -  38.86120821 -76.97986921 38.89729855 -77.05158057
# Latitude and longitude count value -  254
# Source and destination pair -  38.86120821 -76.97986921 38.91053861 -77.02451482
# Latitude and longitude count value -  255
# Source and destination pair -  38.86120821 -76.97986921 38.91053945 -76.99087517
# Latitude and longitude count value -  256
# Source and destination pair -  38.86120821 -76.97986921 38.91161652 -76.96380558
# Latitude and longitude count value -  257
# Source and destination pair -  38.86120821 -76.97986921 38.91169876 -77.03078512
# Latitude and longitude count value -  258
# Source and destination pair -  38.86120821 -76.97986921 38.91190204 -77.03891728
# Latitude and longitude count value -  259
# Source and destination pair -  38.86120821 -76.97986921 38.91194732 -77.00240612
# Latitude and longitude count value -  260
# Source and destination pair -  38.86120821 -76.97986921 38.931117 -77.02552977
# Latitude and longitude count value -  261
# Source and destination pair -  38.86120821 -76.97986921 38.93305058 -77.04034672
# Latitude and longitude count value -  262
# Source and destination pair -  38.86120821 -76.97986921 38.93324072 -76.97641392
# Latitude and longitude count value -  263
# Source and destination pair -  38.86120821 -76.97986921 38.93373104 -77.03125977
# Latitude and longitude count value -  264
# Source and destination pair -  38.86120821 -76.97986921 38.93391182 -77.02779078
# Latitude and longitude count value -  265
# Source and destination pair -  38.86120821 -76.97986921 38.93467316 -77.01049834
# Latitude and longitude count value -  266
# Source and destination pair -  38.86233921 -76.98643833 38.8096324 -77.02283643
# Latitude and longitude count value -  267
# Source and destination pair -  38.86233921 -76.98643833 38.82641682 -76.99597908
# Latitude and longitude count value -  268
# Source and destination pair -  38.86233921 -76.98643833 38.82797649 -77.0066917
# Latitude and longitude count value -  269
# Source and destination pair -  38.86233921 -76.98643833 38.84042391 -76.9833259
# Latitude and longitude count value -  270
# Source and destination pair -  38.86233921 -76.98643833 38.84186464 -77.00192877
# Latitude and longitude count value -  271
# Source and destination pair -  38.86233921 -76.98643833 38.84241783 -77.02307164
# Latitude and longitude count value -  272
# Source and destination pair -  38.86233921 -76.98643833 38.89801164 -77.02717393
# Latitude and longitude count value -  273
# Source and destination pair -  38.86233921 -76.98643833 38.89964623 -77.0618145
# Latitude and longitude count value -  274
# Source and destination pair -  38.86233921 -76.98643833 38.90045743 -77.01456899
# Latitude and longitude count value -  275
# Source and destination pair -  38.86233921 -76.98643833 38.90069992 -77.04713527
# Latitude and longitude count value -  276
# Source and destination pair -  38.86233921 -76.98643833 38.90217222 -77.02994423
# Latitude and longitude count value -  277
# Source and destination pair -  38.86233921 -76.98643833 38.90253233 -77.0425942
# Latitude and longitude count value -  278
# Source and destination pair -  38.86233921 -76.98643833 38.92052368 -77.02428515
# Latitude and longitude count value -  279
# Source and destination pair -  38.86233921 -76.98643833 38.92095151 -77.04301181
# Latitude and longitude count value -  280
# Source and destination pair -  38.86233921 -76.98643833 38.92133926 -77.01773285
# Latitude and longitude count value -  281
# Source and destination pair -  38.86233921 -76.98643833 38.92166117 -77.03981267
# Latitude and longitude count value -  282
# Source and destination pair -  38.86233921 -76.98643833 38.92209241 -77.06361718
# Latitude and longitude count value -  283
# Source and destination pair -  38.86233921 -76.98643833 38.92264653 -76.9977218
# Latitude and longitude count value -  284
# Source and destination pair -  38.86233921 -76.98643833 38.95627562 -77.02605595
# Latitude and longitude count value -  285
# Source and destination pair -  38.86233921 -76.98643833 38.95739565 -77.08688934
# Latitude and longitude count value -  286
# Source and destination pair -  38.86233921 -76.98643833 38.95933179 -77.08133247
# Latitude and longitude count value -  287
# Source and destination pair -  38.86233921 -76.98643833 38.96091005 -77.02366731
# Latitude and longitude count value -  288
# Source and destination pair -  38.86233921 -76.98643833 38.96860273 -77.02366887
# Latitude and longitude count value -  289
# Source and destination pair -  38.86233921 -76.98643833 38.98059882 -77.02917435
# Latitude and longitude count value -  290
# Source and destination pair -  38.86341494 -76.95155624 38.89167154 -76.94292359
# Latitude and longitude count value -  291
# Source and destination pair -  38.86341494 -76.95155624 38.89625783 -77.0146534
# Latitude and longitude count value -  292
# Source and destination pair -  38.86341494 -76.95155624 38.89627629 -77.04292119
# Latitude and longitude count value -  293
# Source and destination pair -  38.86341494 -76.95155624 38.89743112 -77.02045237
# Latitude and longitude count value -  294
# Source and destination pair -  38.86341494 -76.95155624 38.89755634 -76.94484528
# Latitude and longitude count value -  295
# Source and destination pair -  38.86341494 -76.95155624 38.89799732 -76.93258123
# Latitude and longitude count value -  296
# Source and destination pair -  38.86341494 -76.95155624 38.91161652 -76.96380558
# Latitude and longitude count value -  297
# Source and destination pair -  38.86341494 -76.95155624 38.91169876 -77.03078512
# Latitude and longitude count value -  298
# Source and destination pair -  38.86341494 -76.95155624 38.91194732 -77.00240612
# Latitude and longitude count value -  299
# Source and destination pair -  38.86341494 -76.95155624 38.91207602 -77.01922267
# Latitude and longitude count value -  300
# Source and destination pair -  38.86341494 -76.95155624 38.91266636 -77.00635363
# Latitude and longitude count value -  301
# Source and destination pair -  38.86341494 -76.95155624 38.91433016 -77.06071162
# Latitude and longitude count value -  302
# Source and destination pair -  38.86341494 -76.95155624 38.9535716 -77.02581879
# Latitude and longitude count value -  303
# Source and destination pair -  38.86341494 -76.95155624 38.95496321 -77.0105466
# Latitude and longitude count value -  304
# Source and destination pair -  38.86341494 -76.95155624 38.95597956 -77.01789168
# Latitude and longitude count value -  305
# Source and destination pair -  38.86341494 -76.95155624 38.95627562 -77.02605595
# Latitude and longitude count value -  306
# Source and destination pair -  38.86341494 -76.95155624 38.9589056 -77.02443437
# Latitude and longitude count value -  307
# Source and destination pair -  38.86341494 -76.95155624 38.95933179 -77.08133247
# Latitude and longitude count value -  308
# Source and destination pair -  38.86418231 -76.96174845 38.88535555 -76.98085023
# Latitude and longitude count value -  309
# Source and destination pair -  38.86418231 -76.96174845 38.88572762 -77.00098029
# Latitude and longitude count value -  310
# Source and destination pair -  38.86418231 -76.96174845 38.88684045 -76.94360824
# Latitude and longitude count value -  311
# Source and destination pair -  38.86418231 -76.96174845 38.88723589 -76.9932631
# Latitude and longitude count value -  312
# Source and destination pair -  38.86418231 -76.96174845 38.8874763 -76.99880141
# Latitude and longitude count value -  313
# Source and destination pair -  38.86418231 -76.96174845 38.89128932 -76.99678103
# Latitude and longitude count value -  314
# Source and destination pair -  38.86678745 -77.0110482 38.89526734 -76.92957873
# Latitude and longitude count value -  315
# Source and destination pair -  38.86678745 -77.0110482 38.89538647 -77.00081224
# Latitude and longitude count value -  316
# Source and destination pair -  38.86678745 -77.0110482 38.89605239 -76.98694455
# Latitude and longitude count value -  317
# Source and destination pair -  38.86678745 -77.0110482 38.89625783 -77.0146534
# Latitude and longitude count value -  318
# Source and destination pair -  38.86678745 -77.0110482 38.89627629 -77.04292119
# Latitude and longitude count value -  319
# Source and destination pair -  38.8705573 -76.97280455 38.9091533 -77.01064917
# Latitude and longitude count value -  320
# Source and destination pair -  38.8705573 -76.97280455 38.91150838 -77.04595279
# Latitude and longitude count value -  321
# Source and destination pair -  38.8705573 -76.97280455 38.91161652 -76.96380558
# Latitude and longitude count value -  322
# Source and destination pair -  38.8705573 -76.97280455 38.91207602 -77.01922267
# Latitude and longitude count value -  323
# Source and destination pair -  38.8705573 -76.97280455 38.91266636 -77.00635363
# Latitude and longitude count value -  324
# Source and destination pair -  38.87316374 -76.94390024 38.90843889 -77.04771991
# Latitude and longitude count value -  325
# Source and destination pair -  38.87316374 -76.94390024 38.90911577 -77.08943652
# Latitude and longitude count value -  326
# Source and destination pair -  38.87316374 -76.94390024 38.9091533 -77.01064917
# Latitude and longitude count value -  327
# Source and destination pair -  38.87316374 -76.94390024 38.90931566 -77.07455457
# Latitude and longitude count value -  328
# Source and destination pair -  38.87316374 -76.94390024 38.91052778 -77.03968901
# Latitude and longitude count value -  329
# Source and destination pair -  38.87553209 -76.98564186 38.952555 -77.07627268
# Latitude and longitude count value -  330
# Source and destination pair -  38.87553209 -76.98564186 38.95496321 -77.0105466
# Latitude and longitude count value -  331
# Source and destination pair -  38.87553209 -76.98564186 38.95627562 -77.02605595
# Latitude and longitude count value -  332
# Source and destination pair -  38.87553209 -76.98564186 38.95933179 -77.08133247
# Latitude and longitude count value -  333
# Source and destination pair -  38.87581296 -77.01963934 38.82641682 -76.99597908
# Latitude and longitude count value -  334
# Source and destination pair -  38.87581296 -77.01963934 38.85157227 -76.99759371
# Latitude and longitude count value -  335
# Source and destination pair -  38.88178722 -76.98111151 38.9041102 -77.07111089
# Latitude and longitude count value -  336
# Source and destination pair -  38.88178722 -76.98111151 38.90492176 -77.04897729
# Latitude and longitude count value -  337
# Source and destination pair -  38.88178722 -76.98111151 38.9051569 -77.02442185
# Latitude and longitude count value -  338
# Source and destination pair -  38.88178722 -76.98111151 38.90587351 -77.02044541
# Latitude and longitude count value -  339
# Source and destination pair -  38.88178722 -76.98111151 38.90643619 -77.05232668
# Latitude and longitude count value -  340
# Source and destination pair -  38.88516636 -76.96293208 38.92524474 -77.03101925
# Latitude and longitude count value -  341
# Source and destination pair -  38.88516636 -76.96293208 38.92702832 -76.96066267
# Latitude and longitude count value -  342
# Source and destination pair -  38.88516636 -76.96293208 38.92731855 -77.06984356
# Latitude and longitude count value -  343
# Source and destination pair -  38.88516636 -76.96293208 38.92747709 -77.09868874
# Latitude and longitude count value -  344
# Source and destination pair -  38.88516636 -76.96293208 38.92754524 -77.03456233
# Latitude and longitude count value -  345
# Source and destination pair -  38.88826998 -76.95647127 38.92930484 -76.99951564
# Latitude and longitude count value -  346
# Source and destination pair -  38.88826998 -76.95647127 38.93080972 -77.03462047
# Latitude and longitude count value -  347
# Source and destination pair -  38.88826998 -76.95647127 38.931117 -77.02552977
# Latitude and longitude count value -  348
# Source and destination pair -  38.88826998 -76.95647127 38.93324072 -76.97641392
# Latitude and longitude count value -  349
# Source and destination pair -  38.88826998 -76.95647127 38.93373104 -77.03125977
# Latitude and longitude count value -  350
# Source and destination pair -  38.89339859 -76.99260146 38.86678745 -77.0110482
# Latitude and longitude count value -  351
# Source and destination pair -  38.89339859 -76.99260146 38.87417369 -76.99976302
# Latitude and longitude count value -  352
# Source and destination pair -  38.89339859 -76.99260146 38.87553209 -76.98564186
# Latitude and longitude count value -  353
# Source and destination pair -  38.89339859 -76.99260146 38.87786225 -77.03437325
# Latitude and longitude count value -  354
# Source and destination pair -  38.89339859 -76.99260146 38.88023959 -76.98728308
# Latitude and longitude count value -  355
# Source and destination pair -  38.89585383 -76.99236075 38.88362626 -77.01377968
# Latitude and longitude count value -  356
# Source and destination pair -  38.89585383 -76.99236075 38.88572762 -77.00098029
# Latitude and longitude count value -  357
# Source and destination pair -  38.89585383 -76.99236075 38.88723589 -76.9932631
# Latitude and longitude count value -  358
# Source and destination pair -  38.89585383 -76.99236075 38.8874763 -76.99880141
# Latitude and longitude count value -  359
# Source and destination pair -  38.89585383 -76.99236075 38.89092707 -76.99263715
# Latitude and longitude count value -  360
# Source and destination pair -  38.89768883 -76.97849825 38.89254798 -76.95290345
# Latitude and longitude count value -  361
# Source and destination pair -  38.89768883 -76.97849825 38.89538647 -77.00081224
# Latitude and longitude count value -  362
# Source and destination pair -  38.89768883 -76.97849825 38.89625783 -77.0146534
# Latitude and longitude count value -  363
# Source and destination pair -  38.89768883 -76.97849825 38.89627629 -77.04292119
# Latitude and longitude count value -  364
# Source and destination pair -  38.89768883 -76.97849825 38.89743112 -77.02045237
# Latitude and longitude count value -  365
# Source and destination pair -  38.90253233 -77.0425942 38.90643619 -77.05232668
# Latitude and longitude count value -  366
# Source and destination pair -  38.90253233 -77.0425942 38.90645843 -77.06592563
# Latitude and longitude count value -  367
# Source and destination pair -  38.90253233 -77.0425942 38.90720628 -77.04183726
# Latitude and longitude count value -  368
# Source and destination pair -  38.90253233 -77.0425942 38.90852283 -77.04542707
# Latitude and longitude count value -  369
# Source and destination pair -  38.90253233 -77.0425942 38.90855158 -77.03902816
# Latitude and longitude count value -  370
# Source and destination pair -  38.90472373 -76.97379331 38.9010211 -77.05171998
# Latitude and longitude count value -  371
# Source and destination pair -  38.90472373 -76.97379331 38.90180875 -76.99032054
# Latitude and longitude count value -  372
# Source and destination pair -  38.90472373 -76.97379331 38.90217222 -77.02994423
# Latitude and longitude count value -  373
# Source and destination pair -  38.90472373 -76.97379331 38.9022102 -76.95448698
# Latitude and longitude count value -  374
# Source and destination pair -  38.90472373 -76.97379331 38.90253233 -77.0425942
# Latitude and longitude count value -  375
# Source and destination pair -  38.90790805 -77.02447652 38.89538647 -77.00081224
# Latitude and longitude count value -  376
# Source and destination pair -  38.90790805 -77.02447652 38.89612766 -76.99667972
# Latitude and longitude count value -  377
# Source and destination pair -  38.90790805 -77.02447652 38.89625783 -77.0146534
# Latitude and longitude count value -  378
# Source and destination pair -  38.90790805 -77.02447652 38.89627629 -77.04292119
# Latitude and longitude count value -  379
# Source and destination pair -  38.90790805 -77.02447652 38.89743112 -77.02045237
# Latitude and longitude count value -  380
# Source and destination pair -  38.91012147 -76.94455254 38.91012147 -76.94455254
# Latitude and longitude count value -  381
# Source and destination pair -  38.91012147 -76.94455254 38.91053861 -77.02451482
# Latitude and longitude count value -  382
# Source and destination pair -  38.91012147 -76.94455254 38.91053945 -76.99087517
# Latitude and longitude count value -  383
# Source and destination pair -  38.91012147 -76.94455254 38.91071919 -76.98088989
# Latitude and longitude count value -  384
# Source and destination pair -  38.91012147 -76.94455254 38.91161652 -76.96380558
# Latitude and longitude count value -  385
# Source and destination pair -  38.91045564 -77.03551276 38.90492176 -77.04897729
# Latitude and longitude count value -  386
# Source and destination pair -  38.91045564 -77.03551276 38.9051569 -77.02442185
# Latitude and longitude count value -  387
# Source and destination pair -  38.91045564 -77.03551276 38.90643619 -77.05232668
# Latitude and longitude count value -  388
# Source and destination pair -  38.91045564 -77.03551276 38.90645843 -77.06592563
# Latitude and longitude count value -  389
# Source and destination pair -  38.91045564 -77.03551276 38.9070343 -77.03303675
# Latitude and longitude count value -  390
# Source and destination pair -  38.91045564 -77.03551276 38.90720628 -77.04183726
# Latitude and longitude count value -  391
# Source and destination pair -  38.91190204 -77.03891728 38.90843889 -77.04771991
# Latitude and longitude count value -  392
# Source and destination pair -  38.91190204 -77.03891728 38.90855158 -77.03902816
# Latitude and longitude count value -  393
# Source and destination pair -  38.91190204 -77.03891728 38.90879375 -77.03328163
# Latitude and longitude count value -  394
# Source and destination pair -  38.91190204 -77.03891728 38.90931566 -77.07455457
# Latitude and longitude count value -  395
# Source and destination pair -  38.91190204 -77.03891728 38.91045564 -77.03551276
# Latitude and longitude count value -  396
# Source and destination pair -  38.91770549 -77.01609701 38.93809269 -77.00138814
# Latitude and longitude count value -  397
# Source and destination pair -  38.91770549 -77.01609701 38.93848882 -77.09331826
# Latitude and longitude count value -  398
# Source and destination pair -  38.91770549 -77.01609701 38.94372863 -77.07003837
# Latitude and longitude count value -  399
# Source and destination pair -  38.91770549 -77.01609701 38.94506487 -77.03458049
# Latitude and longitude count value -  400
# Source and destination pair -  38.91770549 -77.01609701 38.945163 -77.06020383
# Latitude and longitude count value -  401
# Source and destination pair -  38.91929976 -77.01350976 38.88723589 -76.9932631
# Latitude and longitude count value -  402
# Source and destination pair -  38.91929976 -77.01350976 38.8874763 -76.99880141
# Latitude and longitude count value -  403
# Source and destination pair -  38.91929976 -77.01350976 38.89229315 -77.00206563
# Latitude and longitude count value -  404
# Source and destination pair -  38.91929976 -77.01350976 38.89625783 -77.0146534
# Latitude and longitude count value -  405
# Source and destination pair -  38.91929976 -77.01350976 38.89627629 -77.04292119
# Latitude and longitude count value -  406
# Source and destination pair -  38.92152605 -76.98291135 38.96282848 -77.07706425
# Latitude and longitude count value -  407
# Source and destination pair -  38.92152605 -76.98291135 38.97105024 -77.01351589
# Latitude and longitude count value -  408
# Source and destination pair -  38.92152605 -76.98291135 38.9760153 -77.02344534
# Latitude and longitude count value -  409
# Source and destination pair -  38.92166117 -77.03981267 38.86499612 -76.99692675
# Latitude and longitude count value -  410
# Source and destination pair -  38.92166117 -77.03981267 38.87417369 -76.99976302
# Latitude and longitude count value -  411
# Source and destination pair -  38.92453826 -77.03884076 38.952555 -77.07627268
# Latitude and longitude count value -  412
# Source and destination pair -  38.92453826 -77.03884076 38.95554809 -76.99499807
# Latitude and longitude count value -  413
# Source and destination pair -  38.92453826 -77.03884076 38.95739565 -77.08688934
# Latitude and longitude count value -  414
# Source and destination pair -  38.92453826 -77.03884076 38.95933179 -77.08133247
# Latitude and longitude count value -  415
# Source and destination pair -  38.92453826 -77.03884076 38.96393943 -77.00691037
# Latitude and longitude count value -  416
# Source and destination pair -  38.92542638 -77.09383057 38.91433016 -77.06071162
# Latitude and longitude count value -  417
# Source and destination pair -  38.92542638 -77.09383057 38.91706039 -77.0712757
# Latitude and longitude count value -  418
# Source and destination pair -  38.92542638 -77.09383057 38.91877681 -77.02814588
# Latitude and longitude count value -  419
# Source and destination pair -  38.92542638 -77.09383057 38.92209241 -77.06361718
# Latitude and longitude count value -  420
# Source and destination pair -  38.92542638 -77.09383057 38.92444798 -76.96461733
# Latitude and longitude count value -  421
# Source and destination pair -  38.92562751 -77.04558886 38.88344117 -77.01972757
# Latitude and longitude count value -  422
# Source and destination pair -  38.92562751 -77.04558886 38.88353148 -76.9379037
# Latitude and longitude count value -  423
# Source and destination pair -  38.92562751 -77.04558886 38.88362626 -77.01377968
# Latitude and longitude count value -  424
# Source and destination pair -  38.92562751 -77.04558886 38.88572762 -77.00098029
# Latitude and longitude count value -  425
# Source and destination pair -  38.92562751 -77.04558886 38.88723589 -76.9932631
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e6d53b4f3037> in <module>()
#      40     }
#      41
# ---> 42     r = requests.get('https://maps.googleapis.com/maps/api/directions/json?', params=params, headers=headers)
#      43
#      44     if len(r.json()['routes']) != 0:
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     374                     decode_content=False,
#     375                     retries=self.max_retries,
# --> 376                     timeout=timeout
#     377                 )
#     378
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     557             httplib_response = self._make_request(conn, method, url,
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#     561             # If we're going to release the connection in ``finally:``, then
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _validate_conn(self, conn)
#     782         # Force connect early to allow us to validate the connection.
#     783         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 784             conn.connect()
#     785
#     786         if not conn.is_verified:
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in connect(self)
#     250                                     ca_cert_dir=self.ca_cert_dir,
#     251                                     server_hostname=hostname,
# --> 252                                     ssl_version=resolved_ssl_version)
#     253
#     254         if self.assert_fingerprint:
#
# /Users/kruthika/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.pyc in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     303         context.load_cert_chain(certfile, keyfile)
#     304     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 305         return context.wrap_socket(sock, server_hostname=server_hostname)
#     306
#     307     warnings.warn(
#
# /Users/kruthika/anaconda/lib/python2.7/ssl.pyc in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     350                          suppress_ragged_eofs=suppress_ragged_eofs,
#     351                          server_hostname=server_hostname,
# --> 352                          _context=self)
#     353
#     354     def set_npn_protocols(self, npn_protocols):
#
# /Users/kruthika/anaconda/lib/python2.7/ssl.pyc in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context)
#     577                         # non-blocking
#     578                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 579                     self.do_handshake()
#     580
#     581             except (OSError, ValueError):
#
# /Users/kruthika/anaconda/lib/python2.7/ssl.pyc in do_handshake(self, block)
#     806             if timeout == 0.0 and block:
#     807                 self.settimeout(None)
# --> 808             self._sslobj.do_handshake()
#     809         finally:
#     810             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
from sqlalchemy import create_engine
sqlite_file = 'sqlite://///Users/Kruthika/Projects/DDL/04-team3/census.db'
engine = create_engine(sqlite_file)
from pandas.io import sql
bus_schedules=pd.read_sql_table('bus_schedules', engine)

# %%
from sqlalchemy import create_engine
sqlite_file = 'sqlite://///Users/Kruthika/Projects/DDL/04-team3/census_v2.db'
engine = create_engine(sqlite_file)
from pandas.io import sql
#bus_schedules=pd.read_sql_table('bus_schedules', engine)
bus_schedules.to_sql('bus_schedules', engine)

# %%
transit_compare=pd.read_sql_table('transit_compare', engine)
#transit_compare.to_csv('transit_compare.csv')
transit_compare
# Out:
#                                              unique_id  transit_distance  \
# 0    38.83010611_-76.99690524_38.90643619_-77.05232668               9.2
# 1    38.83010611_-76.99690524_38.90643619_-77.05232668               9.2
# 2    38.83010611_-76.99690524_38.90645843_-77.06592563              10.0
# 3    38.83010611_-76.99690524_38.90645843_-77.06592563              10.0
# 4    38.83010611_-76.99690524_38.90720628_-77.04183726               8.6
# 5    38.83010611_-76.99690524_38.90720628_-77.04183726               8.6
# 6    38.83010611_-76.99690524_38.90843889_-77.04771991               9.2
# 7    38.83010611_-76.99690524_38.90843889_-77.04771991               9.2
# 8     38.83061467_-76.99181518_38.8096324_-77.02283643               3.8
# 9     38.83061467_-76.99181518_38.8096324_-77.02283643               3.8
# 10   38.83061467_-76.99181518_38.82572535_-77.01193256               2.1
# 11   38.83061467_-76.99181518_38.82572535_-77.01193256               2.1
# 12    38.83061467_-76.99181518_38.84042391_-76.9833259               1.3
# 13    38.83061467_-76.99181518_38.84042391_-76.9833259               1.3
# 14   38.83061467_-76.99181518_38.84839225_-76.97380687               1.9
# 15   38.83061467_-76.99181518_38.84839225_-76.97380687               1.9
# 16     38.83061467_-76.99181518_38.897956_-76.99329252               6.4
# 17     38.83061467_-76.99181518_38.897956_-76.99329252               6.4
# 18   38.83061467_-76.99181518_38.89801164_-77.02717393               6.8
# 19   38.83061467_-76.99181518_38.89801164_-77.02717393               6.8
# 20   38.83061467_-76.99181518_38.89876337_-77.00097333               6.8
# 21   38.83061467_-76.99181518_38.89876337_-77.00097333               6.8
# 22   38.83061467_-76.99181518_38.91161652_-76.96380558              10.0
# 23   38.83061467_-76.99181518_38.91161652_-76.96380558              10.0
# 24   38.83061467_-76.99181518_38.91194732_-77.00240612               8.5
# 25   38.83061467_-76.99181518_38.91194732_-77.00240612               8.5
# 26   38.83167957_-76.99563337_38.82626132_-77.00047489               0.7
# 27   38.83167957_-76.99563337_38.82626132_-77.00047489               0.7
# 28   38.83167957_-76.99563337_38.82641682_-76.99597908               0.7
# 29   38.83167957_-76.99563337_38.82641682_-76.99597908               0.7
# ..                                                 ...               ...
# 202  38.85980631_-76.98979257_38.89612766_-76.99667972               3.2
# 203  38.85980631_-76.98979257_38.89612766_-76.99667972               3.2
# 276       38.872557       -76.972373     38.870252     -76.970008
# 277       38.852937       -76.995796     38.851665     -76.997146
# 278       38.891945       -76.951469     38.891896     -76.949553
# 279       38.895934       -76.994861     38.896120     -76.996680
# 280       38.898255       -76.929408     38.895272     -76.929560
# 281       38.847199       -76.972765     38.848182     -76.973678
# 282       38.897217       -76.994885     38.897956     -76.993760
# 283       38.826249       -76.998487     38.826200     -76.996493
# 284       38.868140       -76.981289     38.870240     -76.980779
# 285       38.841937       -77.000385     38.839964     -77.000575
# 286       38.898255       -76.929408     38.895272     -76.929560
# 287       38.879909       -76.983767     38.879889     -76.987189
# 288       38.896104       -76.929757     38.898258     -76.932701
# 289       38.880874       -76.985397     38.879889     -76.987189
# 290       38.838799       -77.002768     38.841650     -77.001667
# 291       38.891829       -76.983593     38.891461     -76.985055
# 292       38.891945       -76.951469     38.891896     -76.949553
#
#      distance_in_miles  duration_in_mins    walk_class
# 0              41063.4            4866.0  Poor transit
# 1               1031.0               5.0  Poor transit
# 2                913.0               4.0  Poor transit
# 3                834.3              10.0  Poor transit
# 4                778.6              16.0  Poor transit
# 5                778.3              11.0  Poor transit
# 6                772.0               4.0  Poor transit
# 7                771.5              13.0  Poor transit
# 8                745.8              20.0  Poor transit
# 9                715.6              15.0  Poor transit
# 10               607.3               9.0  Poor transit
# 11               607.3               9.0  Poor transit
# 12               585.1               5.0  Poor transit
# 13               584.0               3.0  Poor transit
# 14               565.8              18.0  Poor transit
# 15               565.7              17.0  Poor transit
# 16               565.5              14.0  Poor transit
# 17               565.5              13.0  Poor transit
# 18               565.4              11.0  Poor transit
# 19               565.3               8.0  Poor transit
# 20               545.1               6.0  Poor transit
# 21               526.0              21.0  Poor transit
# 22               509.3              11.0  Poor transit
# 23               493.1              24.0  Poor transit
# 24               493.0              23.0  Poor transit
# 25               480.1              23.0  Poor transit
# 26               479.1               4.0  Poor transit
# 27               470.1              23.0  Poor transit
# 28               440.4              11.0  Poor transit
# 29               421.0              22.0  Poor transit
# ..                 ...               ...           ...
# 263                0.6              12.0  Good transit
# 264                0.6              12.0  Good transit
# 265                0.6              13.0  Good transit
# 266                0.6              12.0  Good transit
# 267                0.5              10.0  Good transit
# 268                0.5              13.0  Good transit
# 269                0.5              10.0  Good transit
# 270                0.5               9.0  Good transit
# 271                0.5              11.0  Good transit
# 272                0.5              11.0  Good transit
# 273                0.5               8.0  Good transit
# 274                0.4               9.0  Good transit
# 275                0.4               7.0  Good transit
# 276                0.4               9.0  Good transit
# 277                0.4               8.0  Good transit
# 278                0.4               8.0  Good transit
# 279                0.4               8.0  Good transit
# 280                0.4               9.0  Good transit
# 281                0.3               8.0  Good transit
# 282                0.3               6.0  Good transit
# 283                0.3               7.0  Good transit
# 284                0.3               5.0  Good transit
# 285                0.3               7.0  Good transit
# 286                0.3               9.0  Good transit
# 287                0.3               7.0  Good transit
# 288                0.3               6.0  Good transit
# 289                0.2               6.0  Good transit
# 290                0.2               5.0  Good transit
# 291                0.2               5.0  Good transit
# 292                0.2               5.0  Good transit
#
# [293 rows x 9 columns]
